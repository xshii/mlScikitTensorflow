# %% [markdown]
# #  Dimensionality reduction

# %% [markdown]
# *curse of dimensionality*: thousands or even millions of features for each training instance

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#The-curse-of-dimensionality" data-toc-modified-id="The-curse-of-dimensionality-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>The curse of dimensionality</a></span></li><li><span><a href="#Main-approaches-for-dimensionality-reduction" data-toc-modified-id="Main-approaches-for-dimensionality-reduction-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Main approaches for dimensionality reduction</a></span><ul class="toc-item"><li><span><a href="#Projection" data-toc-modified-id="Projection-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Projection</a></span></li><li><span><a href="#Manifold-learning" data-toc-modified-id="Manifold-learning-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Manifold learning</a></span></li></ul></li><li><span><a href="#PCA" data-toc-modified-id="PCA-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>PCA</a></span><ul class="toc-item"><li><span><a href="#Preserving-the-variance" data-toc-modified-id="Preserving-the-variance-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Preserving the variance</a></span></li><li><span><a href="#Principal-component" data-toc-modified-id="Principal-component-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Principal component</a></span></li><li><span><a href="#SVD" data-toc-modified-id="SVD-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>SVD</a></span></li><li><span><a href="#Projecting-down-to-d-dimensions---np.linalg.svd()" data-toc-modified-id="Projecting-down-to-d-dimensions---np.linalg.svd()-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Projecting down to d dimensions - <code>np.linalg.svd()</code></a></span></li><li><span><a href="#SL-PCA---decomposition:PCA" data-toc-modified-id="SL-PCA---decomposition:PCA-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>SL PCA - <code>decomposition:PCA</code></a></span><ul class="toc-item"><li><span><a href="#access-the-principle-components-using-the-.components_-variable" data-toc-modified-id="access-the-principle-components-using-the-.components_-variable-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>access the principle components using the <code>.components_</code> variable</a></span></li><li><span><a href="#Explained-variance-ratio---.explained_variance_ratio_" data-toc-modified-id="Explained-variance-ratio---.explained_variance_ratio_-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>Explained variance ratio - <code>.explained_variance_ratio_</code></a></span></li><li><span><a href="#Choosing-the-right-number-of-dimensions-n_components=(0~1)" data-toc-modified-id="Choosing-the-right-number-of-dimensions-n_components=(0~1)-3.5.3"><span class="toc-item-num">3.5.3&nbsp;&nbsp;</span>Choosing the right number of dimensions <code>n_components=(0~1)</code></a></span></li></ul></li><li><span><a href="#PCA-for-Compression---.inverse_transformation" data-toc-modified-id="PCA-for-Compression---.inverse_transformation-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>PCA for Compression - <code>.inverse_transformation</code></a></span></li><li><span><a href="#Incremental-PCA---decomposition:IncrementalPCA" data-toc-modified-id="Incremental-PCA---decomposition:IncrementalPCA-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Incremental PCA - <code>decomposition:IncrementalPCA</code></a></span><ul class="toc-item"><li><span><a href="#split-array---np.array_split()" data-toc-modified-id="split-array---np.array_split()-3.7.1"><span class="toc-item-num">3.7.1&nbsp;&nbsp;</span>split array - <code>np.array_split()</code></a></span></li><li><span><a href="#split-file---np.memmap()" data-toc-modified-id="split-file---np.memmap()-3.7.2"><span class="toc-item-num">3.7.2&nbsp;&nbsp;</span>split file - <code>np.memmap()</code></a></span></li></ul></li><li><span><a href="#Randomized-PCA---svd_solver='randomized'" data-toc-modified-id="Randomized-PCA---svd_solver='randomized'-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Randomized PCA - <code>svd_solver='randomized'</code></a></span></li><li><span><a href="#Kernel-PCA---decomposition:KernelPCA" data-toc-modified-id="Kernel-PCA---decomposition:KernelPCA-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Kernel PCA - <code>decomposition:KernelPCA</code></a></span><ul class="toc-item"><li><span><a href="#Turning-via-GridSearch,-.best_params_" data-toc-modified-id="Turning-via-GridSearch,-.best_params_-3.9.1"><span class="toc-item-num">3.9.1&nbsp;&nbsp;</span>Turning via <code>GridSearch</code>, <code>.best_params_</code></a></span></li><li><span><a href="#Turning-via-reconstruction-error-reduction-pre-image" data-toc-modified-id="Turning-via-reconstruction-error-reduction-pre-image-3.9.2"><span class="toc-item-num">3.9.2&nbsp;&nbsp;</span>Turning via reconstruction error reduction <em>pre-image</em></a></span></li></ul></li></ul></li><li><span><a href="#LLE---manifold:LocallyLinearEmbedding" data-toc-modified-id="LLE---manifold:LocallyLinearEmbedding-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>LLE - <code>manifold:LocallyLinearEmbedding</code></a></span><ul class="toc-item"><li><span><a href="#LLE:-Steps" data-toc-modified-id="LLE:-Steps-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>LLE: Steps</a></span></li></ul></li><li><span><a href="#Other-dimensionality-reduction-techniques" data-toc-modified-id="Other-dimensionality-reduction-techniques-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Other dimensionality reduction techniques</a></span></li></ul></div>

# %% [markdown]
# ## The curse of dimensionality
# * slow the training
# * make it much harder to find a good solution
# * not good for data visualization
# * more risk of overfitting

# %% [markdown]
# ## Main approaches for dimensionality reduction

# %% [markdown]
# ### Projection

# %% [markdown]
# project 3D to 2D

# %% [markdown]
# ###  Manifold learning

# %% [markdown]
# a 2D manifold is a 2D shape that can be bent and twisted in a higher-dimensional space.
#
# Many dimensionality reduction algorithms work by modeling the *manifold* on which the training instances lie; this is called *Manifold learning*. It relies on the *manifold assumption*, also called *manifold hypothesis*:
#
#         most real-world high-dimensional datasets lie close to a much lower-dimensional manifold

# %% [markdown]
# **it all depends on the dataset**

# %% [markdown]
# ## PCA
# **PCA** (Principal Component Analysis): first it identifies the hyperplane that lies closest to the data, and then it projects the data onto it.

# %% [markdown]
# ### Preserving the variance

# %% [markdown]
# select the subspace that preserves the maximum amount of variance, as it will most likely lose less information than the other projections.
#
#         PCA minimizes the mean squared distance between the original dataset and its projection onto that axis

# %% [markdown]
# ### Principal component

# %% [markdown]
# Principal component (PC) the axis that accounts for the largest amount of variance in the current variance.

# %% [markdown]
# ### SVD

# %% [markdown]
# **SVD**(Singular Value Decomposition): decompose the training set matrix $\mathbf{X}$ into the dot product of three matrices
# $$\bf{U}\cdot \Sigma\cdot\bf{V}^T$$

# %% [markdown]
# * $\bf{V}^T=[\bf{C}_1,\bf{C}_2,...,\bf{C}_n]$ contains all the principal components.

# %% [markdown]
# <div class="burk">
# Data needs centered (SL will do this for users.) </div><i class="fa fa-lightbulb-o "></i>

# %% [markdown]
# ### Projecting down to d dimensions - `np.linalg.svd()`

# %% [markdown]
# $$\bf{X}_{d_proj}=\bf{x}\cdot\bf{W}_d$$

# %% [markdown]
# * $\bf{W}_d=[\bf{C}_1,...,\bf{C}_d]$

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

X1 = np.linspace(0,5,100)
X2 = 2 * X1 + 2 + 2*np.random.rand(len(X1))
X = np.hstack((X1.reshape(-1,1),X2.reshape(-1,1)))
plt.scatter(X[:,0],X[:,1])
X_centered = X - X.mean(axis=0)
U, s, V = np.linalg.svd(X_centered)
c1 = V.T[:, 0]
c2 = V.T[:, 1]

W2 = V.T[:, :2]
X2D = X_centered.dot(W2)
c1
# Out:
# array([0.44161288, 0.8972057 ])

# %% [markdown]
# ### SL PCA - `decomposition:PCA`

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 2)
X2D = pca.fit_transform(X)

# %% [markdown]
# #### access the principle components using the `.components_` variable

# %% [markdown]
# for example, the first principal component is equal to `pca.components_.T[:,0]`

# %%
pca.components_.T[:,0]
# Out:
# array([-0.43339205, -0.90120549])

# %% [markdown]
# #### Explained variance ratio - `.explained_variance_ratio_`

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.9943917 0.0056083]

# %% [markdown]
# This tells that \[0\]% of the dataset's variance lies along the first axis, ....

# %% [markdown]
# #### Choosing the right number of dimensions `n_components=(0~1)`

# %% [markdown]
# Choose the number of dimensions that add up to a sufficiently large portion of the variance.

# %%
pca = PCA()
pca.fit(X)
cumsum = np.cumsum(pca.explained_variance_ratio_)
d = np.argmax(cumsum >= 0.95) + 1

plt.scatter(np.arange(len(cumsum)),cumsum)

# %% [markdown]
# Alternatively and better, set `n_components=` a float between 0.0 and 1.0, indicating the ratio of variance you wish to preserve

# %%
pca = PCA(n_components=0.95)
X_reduced = pca.fit_transform(X)

# %% [markdown]
# ### PCA for Compression - `.inverse_transformation`

# %% [markdown]
# `.inverse_transformation(reduced_dimension_data)`: reconstruct the data.
# * *reconstruction error*: the mean squared distance between the original data and the reconstructed data.

# %% [markdown]
# $\bf{X}_{recovered}=\bf{X}_{d_proj}\cdot\bf{W}_d^T$

# %% [markdown]
# ### Incremental PCA - `decomposition:IncrementalPCA`

# %% [markdown]
# **IPCA** (Incremental PCA): split the training set into mini-batches and feed an IPCA algorithm one mini-batch at a time.

# %% [markdown]
# #### split array - `np.array_split()`

# %%
from sklearn.decomposition import IncrementalPCA
n_batches = 100
inc_pca = IncrementalPCA(n_components=154)

#for X_batch in np.array_split(X_mnist, n_batches):
#    inc_pca.partial_fit(X_batch)
#X_minist_reduced = inc_pca.transform(X_mnist)

# %% [markdown]
# #### split file - `np.memmap()`

# %% [markdown]
# ```{python}
# X_mm = np.memmap(filename, dtype='float32',mode='readonly',shape=(m,n))
#
# batch_size = m // n_batches
# inc_pca = IncrementalPCA(n_components=154, batch_size=batch_size)
# inc_pca.fit(X_mm)
# ```

# %% [markdown]
# ### Randomized PCA - `svd_solver='randomized'`

# %% [markdown]
# the complexity is $O(m\times d^2)+O(d^3)$ instead of $O(m\times n^2)+O(n^3)$

# %%
rnd_pca = PCA(n_components=154, svd_solver="randomized")

# %% [markdown]
# ### Kernel PCA - `decomposition:KernelPCA`

# %% [markdown]
# **Unsupervised learning algorithm** but the dimensionality reduction is often a preparation step for a supervised learning task. Use grid search to select the kernel and hyperparameters that lead to the best performance on that task.
#
#
# It is often good at preserving clusters of instances after projection, or sometimes even unrolling datasets that lie close to a twisted manifold.

# %% [markdown]
# ```
# from sklearn.decomposition import KernelPCA
# rbf_pca = KernelPCA(n_components = 2, kernel="rbf", gamma=0.04)
# X_reduced = rbf_pca.fit_transform(X)
# ```

# %% [markdown]
# #### Turning via `GridSearch`, `.best_params_`

# %%
from sklearn.decomposition import KernelPCA

from sklearn.model_selection import GridSearchCV 
from sklearn.linear_model import LogisticRegression 
from sklearn.pipeline import Pipeline


clf = Pipeline([
            ("kpca", KernelPCA(n_components=2)),
            ("log_reg", LogisticRegression())
])
param_grid = [{
    "kpca__gamma": np.linspace(0.03, 0.05, 10),
    "kpca__kernel": ["rbf", "sigmoid"]
}]

grid_search = GridSearchCV(clf, param_grid, cv=3)
#grid_search.fit(X, y)

# %% [markdown]
# #### Turning via reconstruction error reduction *pre-image*

# %% [markdown]
# Original space -(kPCA)-> Reduced space
#
# $\Updownarrow$ pre-image error &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;            $\Downarrow$ Reconstruction
#
# Reconstruction pre-image(3d) $\Leftarrow$ Feature space

# %%
rbf_pca = KernelPCA(n_components = 2, kernel="rbf", gamma=0.0433,
                        fit_inverse_transform=True)

# %% [markdown]
# ```
# X_reduced = rbf_pca.fit_transform(X)
# X_preimage = rbf_pca.inverse_transform(X_reduced)
# from sklearn.metrics import mean_squared_error
# mean_squared_error(X, X_preimage)
# ```

# %% [markdown]
# ## LLE - `manifold:LocallyLinearEmbedding`

# %% [markdown]
# **LLE**(Locally Linear Embedding): *nonlinear dimensionality reduction* (NLDR) technique.
#
# It is Manifold learning technique that does not rely on projections like the previous algorithms.
#
# 1. LLE measures how each training instance linearly relates to its closest neighbors
# 2. LLE looks for a low-dimensional representation of the training set where these local relationships are best preserved.

# %%
from sklearn.datasets import make_swiss_roll
from mpl_toolkits.mplot3d import Axes3D
swish_roll = make_swiss_roll(noise=0,random_state=43,n_samples=400)
swish_roll[0]
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(swish_roll[0][:,0],swish_roll[0][:,1],swish_roll[0][:,2],c=swish_roll[1])
plt.show()

# %%
plt.figure()
plt.subplot(1,3,1)
plt.scatter(swish_roll[0][:,0],swish_roll[0][:,1],c=swish_roll[1])
plt.subplot(1,3,2)
plt.scatter(swish_roll[0][:,0],swish_roll[0][:,2],c=swish_roll[1])
plt.subplot(1,3,3)
plt.scatter(swish_roll[0][:,1],swish_roll[0][:,2],c=swish_roll[1])

# %%
from sklearn.manifold import LocallyLinearEmbedding
lle = LocallyLinearEmbedding(n_components=2, n_neighbors=13)
X= swish_roll[0]
X_reduced = lle.fit_transform(X)

# %%
plt.scatter(X_reduced[:,0],X_reduced[:,1],c=swish_roll[1])

# %% [markdown]
# ### LLE: Steps

# %% [markdown]
# 1. For each training instance $\bf{x}^{(i)}$, the algorithm identifies its $k$ closest neighbors. Then find the weight $w_{i,j}$ such that the squared distance between $\bf{x}^{(i)}$ and $\sum_{j=1}^mw_{i,j}\bf{x}^{(i)}$ is as small as possible, assuming $w_{i,j}=0$ if $\bf{x}^{(j)}$ is not one of the $k$ closest neighbors of $\bf{x}^{(i)}$.

# %% [markdown]
# $$\hat{\bf{W}}=\arg\min_\bf{W}\sum_{i=1}^m|| \bf{x}^{(i)} - \sum_{j=1}^mw_{i,j}\bf{x}^{(i)}||^2$$
#
# subject to
# * $w_{i,j}=0$ if $\bf{x}^{(j)}$ is not one of the $k$ closest neighbors of $\bf{x}^{(i)}$
# * $\sum_{j=1}^mw_{i,j}=1$ for $i=1,2,...,m$

# %% [markdown]
# 2. map the training instances into a d-dimensional space ($d< n$) while preserving these local relationships as much as possible.

# %% [markdown]
# $$\hat{\bf{Z}}=\arg\min_\bf{Z}\sum_{i=1}^m|| \bf{z}^{(i)} - \sum_{j=1}^mw_{i,j}\bf{z}^{(i)}||^2$$

# %% [markdown]
# SL's LLE implementation has the computational complexity
# * $O(m\log(m)n\log(k))$ for finding the $k$ nearest neighbors
# * $O(mnk^3)$ for optimizing the weights
# * $O(dm^2)$ for constructing the low-dimensional representations. $m^2$ in the last term makes this algorithm scale poorly to very large datasets

# %% [markdown]
# ## Other dimensionality reduction techniques

# %% [markdown]
# * *Multidimensional Scaling* (MDS) reduces dimensionality while trying to preserve the distances between the instances
# * *Isomap* creates a graph by connecting each instance to its nearest neighbors, then reduces dimensionality while trying to preserve the *geodesic distances* (the number of nodes on the shortest path between these nodes) between the instances.
# * *t-Distributed Stochastic Neighbor Embedding* (t-SNE) reduces dimensionality while trying to keep similar instances close and dissimilar instances apart. It is mostly used for visualization, in particular to visualize clusters of instances in high-dimensional space (e.g., to visualize the MNIST images in 2D).
# * *Linear Discriminant Analysis* (LDA) is actually a classification algorithm, but during training it learns the most discriminative axes between the classes, and these axes can then be used to define a hyperplane onto which to project the data. The benefit is that the projection will keep classes as far apart as possible, so LDA is a good technique to reduce dimensionality before running another classification algorithm such as an SVM classifier.
